# %%
# pip install PyTube

# %%
# pip install python-pptx

# %%
# pip install youtube-transcript-api

# %%
import glob
from Python_Functions.userFunctions import pptToText
from Python_Functions.userFunctions import youtubeTranscriptApiData

# %%
pptList = [g for g in glob.glob('../../Data/text_univ_chichago/*.pptx')]
pptDf = [pptToText(p) for p in pptList]

# %%
pptDf[0].to_csv('scraping_data/pptFlamingo.csv')
pptDf[0].head()
# Out:
#                                         PPT Sub Text  \
# 0                                            PEAFOWL
# 1  Peacock is the National bird of India. It has ...
# 2  Food: Peafowls are omnivorous. They love to ea...
# 3                                     Eggs of Peahen
# 4                             Source: peacocksuk.com
#
#                                             PPT File
# 0  ../../Data/text_univ_chichago/birds_intro_peaf...
# 1  ../../Data/text_univ_chichago/birds_intro_peaf...
# 2  ../../Data/text_univ_chichago/birds_intro_peaf...
# 3  ../../Data/text_univ_chichago/birds_intro_peaf...
# 4  ../../Data/text_univ_chichago/birds_intro_peaf...

# %%
vidDataDfFlamingo = youtubeTranscriptApiData(searchText = 'flamingo kid education', category= 'Flamingo', i = 50)
vidDataDfFlamingo.to_csv('scraping_data/videoFlamingo.csv')
vidDataDfFlamingo.head()
# Out:
# Percentage of Videos w/Transcript: 20.895522388059703%
#                                                 text   start  duration  \
# 0                        You're watching FreeSchool!   2.628     2.796
# 1                       Let's learn about flamingos!   8.779     2.298
# 2  Flamingos are tall, pink wading birds that\nca...  13.168     7.510
# 3  as well as the warm coastal regions of North\n...  21.125     6.176
# 4  Because they are water birds, flamingos live\n...  28.654     5.990
#
#       Video ID                                              Title  \
# 0  _gs4XfbYPKc  All About Flamingos for Kids: Animal Videos fo...
# 1  _gs4XfbYPKc  All About Flamingos for Kids: Animal Videos fo...
# 2  _gs4XfbYPKc  All About Flamingos for Kids: Animal Videos fo...
# 3  _gs4XfbYPKc  All About Flamingos for Kids: Animal Videos fo...
# 4  _gs4XfbYPKc  All About Flamingos for Kids: Animal Videos fo...
#
#    Age Restricted  Length (min)  Views (thous)  Category
# ...

# %%
pptDf[1].to_csv('scraping_data/pptPeafowl.csv')
pptDf[1].head()
# Out:
#                                         PPT Sub Text  \
# 0                                           Flamingo
# 1  Flamingo is about 110 to 150 cm tall and weigh...
# 2
# 3  Hey, I am Flame…I think children like my pink ...
# 4  Food: Flamingos are omnivorous. They love to f...
#
#                                             PPT File
# 0  ../../Data/text_univ_chichago/birds_intro_flam...
# 1  ../../Data/text_univ_chichago/birds_intro_flam...
# 2  ../../Data/text_univ_chichago/birds_intro_flam...
# 3  ../../Data/text_univ_chichago/birds_intro_flam...
# 4  ../../Data/text_univ_chichago/birds_intro_flam...

# %%
vidDataDfPeafowl = youtubeTranscriptApiData(searchText = 'peafowl kid education', category= 'Peafowl', i = 50)
vidDataDfPeafowl.to_csv('scraping_data/videoPeafowl.csv')
vidDataDfPeafowl.head()
# Out:
# Percentage of Videos w/Transcript: 27.536231884057973%
#                                                 text  start  duration  \
# 0  Peacock is a bit of a misnomer, but because \n...   0.00      4.80
# 1  we’re going to stick with it, but if \nyou wan...   4.80      3.44
# 2  ‘peacock’ is specifically in reference to \nma...   8.24      5.44
# 3  babies are called ‘peachicks.’ As a whole, the...  13.68      5.92
# 4  The most common, and probably the most familia...  19.60      4.56
#
#       Video ID                                              Title  \
# 0  EkJvstgd7oc  Peacock Facts: FACTS about PEAFOWL 🦚 Animal Fa...
# 1  EkJvstgd7oc  Peacock Facts: FACTS about PEAFOWL 🦚 Animal Fa...
# 2  EkJvstgd7oc  Peacock Facts: FACTS about PEAFOWL 🦚 Animal Fa...
# 3  EkJvstgd7oc  Peacock Facts: FACTS about PEAFOWL 🦚 Animal Fa...
# 4  EkJvstgd7oc  Peacock Facts: FACTS about PEAFOWL 🦚 Animal Fa...
#
#    Age Restricted  Length (min)  Views (thous) Category
# ...

# %%
pptDf[2].to_csv('scraping_data/pptTailorBird.csv')
pptDf[2].head()
# Out:
#                                         PPT Sub Text  \
# 0  Ants are one of the most common insects that l...
# 1  Queen ant: The queen ant is the leader of the ...
# 2  Caste of ants: https://in.pinterest.com/pin/73...
# 3  In our garden, we see little black ants, carpe...
# 4  Little black ants:\nThey live in large colonie...
#
#                                             PPT File
# 0  ../../Data/text_univ_chichago/insects_intro_an...
# 1  ../../Data/text_univ_chichago/insects_intro_an...
# 2  ../../Data/text_univ_chichago/insects_intro_an...
# 3  ../../Data/text_univ_chichago/insects_intro_an...
# 4  ../../Data/text_univ_chichago/insects_intro_an...

# %%
# modified
vidDataDfTailorBird = youtubeTranscriptApiData(searchText ='tailor bird for kid education',category= 'TailorBird', i = 50)
vidDataDfTailorBird.to_csv('scraping_data/videoTailorBird.csv')
vidDataDfTailorBird.head()
# Out:
# Percentage of Videos w/Transcript: 21.73913043478261%
#                                                 text  start  duration  \
# 0                              Introduction to Birds   4.82      2.97
# 1  There are nearly 10,000 different kinds of\nbi...   7.79      4.05
# 2         They come in all sizes, shapes and breeds.  11.84      4.86
# 3             Some live on water and others on land.  16.70      3.62
# 4  Some live in very cold places, while others\nl...  20.32      5.23
#
#       Video ID                                              Title  \
# 0  kzRkWvwqkNI  Birds for Kids | Learn all about Birds in this...
# 1  kzRkWvwqkNI  Birds for Kids | Learn all about Birds in this...
# 2  kzRkWvwqkNI  Birds for Kids | Learn all about Birds in this...
# 3  kzRkWvwqkNI  Birds for Kids | Learn all about Birds in this...
# 4  kzRkWvwqkNI  Birds for Kids | Learn all about Birds in this...
#
#    Age Restricted  Length (min)  Views (thous)    Category
# ...

# %%
# vidDataDf_TailorBird = youtubeTranscriptApiData(searchText =  'tailor bird kid education', category='Tailor Bird' , i = 30)
# vidDataDf_TailorBird.to_csv('scraping_data/videoTailorBird.csv')
# vidDataDf_TailorBird.head()

# %%
pptDf[3].to_csv('scraping_data/pptAnt.csv')
pptDf[3].head()
# Out:
#                                         PPT Sub Text  \
# 0  Tailorbird\nTailorbird- The Tailorbird has tai...
# 1  Hey, I am Tinky, a Tailorbird. Do you know tha...
# 2  Tailorbird: https://www.nhm.ac.uk/discover/the...
# 3  Tailorbird has a rare kind of beak. It uses it...
# 4  Tailorbird beak: https://en.wikipedia.org/wiki...
#
#                                             PPT File
# 0  ../../Data/text_univ_chichago/birds_intro_tail...
# 1  ../../Data/text_univ_chichago/birds_intro_tail...
# 2  ../../Data/text_univ_chichago/birds_intro_tail...
# 3  ../../Data/text_univ_chichago/birds_intro_tail...
# 4  ../../Data/text_univ_chichago/birds_intro_tail...

# %%
vidDataDfAnt = youtubeTranscriptApiData(searchText ='ant kid education',category= 'Ant', i = 50)
vidDataDfAnt.to_csv('scraping_data/videoAnt.csv')
vidDataDfAnt.head()
# Out:
# Percentage of Videos w/Transcript: 27.536231884057973%
#                                      text  start  duration     Video ID  \
# 0  welcome to my tree house come and look  0.560     3.520  cXUCUvcscXs
# 1                                 at this  2.560     3.520  cXUCUvcscXs
# 2                     this is my ant farm  4.080     4.559  cXUCUvcscXs
# 3      ants are amazing creatures lots of  6.080     4.479  cXUCUvcscXs
# 4  insects live by themselves and have to  8.639     4.241  cXUCUvcscXs
#
#                           Title  Age Restricted  Length (min)  Views (thous)  \
# 0  Children Learn About The Ant           False      5.333333        921.491
# 1  Children Learn About The Ant           False      5.333333        921.491
# 2  Children Learn About The Ant           False      5.333333        921.491
# 3  Children Learn About The Ant           False      5.333333        921.491
# 4  Children Learn About The Ant           False      5.333333        921.491
#
#   Category
# ...

# %%
pptDf[4].to_csv('scraping_data/pptBeetle.csv')
pptDf[4].head()
# Out:
#                                         PPT Sub Text  \
# 0  We see many insects around us. Some have wings...
# 1    Beetle: https://unsplash.com/photos/emTCWiq2txk
# 2  Lady Bug:\nLadybugs are tiny beetles. They are...
# 3  Lady Bug: https://in.pinterest.com/pin/1266706...
# 4  Appearance:\nThey have an elliptical body.\nTh...
#
#                                             PPT File
# 0  ../../Data/text_univ_chichago/insects_intro_be...
# 1  ../../Data/text_univ_chichago/insects_intro_be...
# 2  ../../Data/text_univ_chichago/insects_intro_be...
# 3  ../../Data/text_univ_chichago/insects_intro_be...
# 4  ../../Data/text_univ_chichago/insects_intro_be...

# %%
vidDataDfBeetle = youtubeTranscriptApiData(searchText = 'beetle kid education',  category= 'Beetle', i = 50)
vidDataDfBeetle.to_csv('scraping_data/videoBeetle.csv')
vidDataDfBeetle.head()
# Out:
# Percentage of Videos w/Transcript: 26.470588235294116%
#                                                 text   start  duration  \
# 0                                               Bugs   7.370     1.000
# 1  It is estimated that there are about 10 quinti...   8.370     6.540
# 2               That’s a 10 with 18 zeros behind it!  14.910     4.770
# 3  If you took all those bugs and divided them\nb...  19.680     6.259
# 4                   would have over 2,000 bugs each!  25.939     3.901
#
#       Video ID                                              Title  \
# 0  ZZcYUQhk4R0  Insects for Kids | Have fun learning all about...
# 1  ZZcYUQhk4R0  Insects for Kids | Have fun learning all about...
# 2  ZZcYUQhk4R0  Insects for Kids | Have fun learning all about...
# 3  ZZcYUQhk4R0  Insects for Kids | Have fun learning all about...
# 4  ZZcYUQhk4R0  Insects for Kids | Have fun learning all about...
#
#    Age Restricted  Length (min)  Views (thous) Category
# ...
